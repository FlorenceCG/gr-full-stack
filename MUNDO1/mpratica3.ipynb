# %% [markdown]
# Universidade Estácio de Sá
#
# Curso: Desenvolvimento Full Stack
#
# Disciplina: Estruturando Dados
#
# Turma: 2022.2
#
# Semestre Letivo: 1
#
# Título da Prática: Implementar um algoritmo para obter o conjunto das partes de um conjunto.
#
# Objetivo da Prática: Utilizar estruturas de dados como listas, comandos condicionais e iterativos. Entrar com uma lista que representa um conjunto e o programa deve produzir o seu respectivo conjunto das partes.
#
# Aluno: Florence Cristina Gonçalves
#
# LinkedIn: www.linkedin.com/in/florencegoncalves

# %%
entrada = input('Insira os elementos do conjunto separados por espaço: ').split()
# Out:
# Insira os elementos do conjunto separados por espaço: 1 2 3 4

# %%
conjunto_partes = []

N = len(entrada)

for i in range(2**N):
    combo = []

    for j in range(N):
        if (i >> j) % 2 == 1:
            combo.append(entrada[j])

    conjunto_partes.append(combo)

# %%
print(conjunto_partes)
# Out:
# [[], ['1'], ['2'], ['1', '2'], ['3'], ['1', '3'], ['2', '3'], ['1', '2', '3'], ['4'], ['1', '4'], ['2', '4'], ['1', '2', '4'], ['3', '4'], ['1', '3', '4'], ['2', '3', '4'], ['1', '2', '3', '4']]
